# %%
import datetime
from dateutil.relativedelta import relativedelta
import math
import pickle

import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import mlflow
# from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
# from hyperopt.pyll import scope
import optuna
from sqlalchemy import create_engine
import pymysql

# %% [markdown]
# ### MlFlow setup
# * Tracking server: no
# * Backend store: local filesystem
# * Artifacts store: local filesystem

# %%
mlflow.set_tracking_uri("http://127.0.0.1:80")

# %% [markdown]
# ### MySQL data

# %%
connection_string = 'mysql+pymysql://application:passpass@127.0.0.1'
database = 'retail_dataset_kaggle'

# %%
def get_db_connection(mysql_con_string, database_name):
    # sqlEngine       = create_engine('mysql+pymysql://application:passpass@127.0.0.1/retail_data', pool_recycle=3600)
    sqlEngine       = create_engine(mysql_con_string + '/' + database_name, pool_recycle=3600)
    dbConnection    = sqlEngine.connect()
    return dbConnection

# %%
con =  get_db_connection(connection_string, database)

# %% [markdown]
# ### Prediction Monthly of sales for all stores and SKUS

# %% [markdown]
# ### Feature Engineering

# %%
features_df  = pd.read_sql("select * from retail_dataset_kaggle.store_date_month_agg", con)

# %%
features_df.dtypes
# Out:
# Store                 int64
# year_month_first     object
# Temperature         float64
# Fuel_Price          float64
# MarkDown1           float64
# MarkDown2           float64
# MarkDown3           float64
# MarkDown4           float64
# MarkDown5           float64
# CPI                 float64
# Unemployment        float64
# IsHoliday             int64
# month                 int64
# dtype: object

# %%
sales_df =  pd.read_sql("select * from retail_dataset_kaggle.sales_monthly_agg", con)

# %%
sales_df.dtypes
# Out:
# Store                 int64
# Dept                  int64
# year_month_first     object
# Monthly_Sales       float64
# dtype: object

# %%
stores_df = pd.read_sql("select * from retail_dataset_kaggle.store", con)

# %%
feature_eng = pd.merge(stores_df, sales_df, on="Store")
feature_eng = pd.merge(features_df, feature_eng, on=["Store", "year_month_first"])
feature_eng['year_month_first'] =  pd.to_datetime(feature_eng['year_month_first'])
feature_eng["month"] = feature_eng['year_month_first'].dt.month

# %%
feature_eng.head(2)
# Out:
#    Store year_month_first  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1       2010-02-01        41.12      2.5545        NaN        NaN
# 1      1       2010-02-01        41.12      2.5545        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0        NaN        NaN        NaN  211.236828         8.106          1
# 1        NaN        NaN        NaN  211.236828         8.106          1
#
#    month Type    Size  Dept  Monthly_Sales
# 0      2    A  151315     1      131963.08
# 1      2    A  151315     2      187509.77

# %% [markdown]
# ### Created Features

# %%
def fourier_terms(value, period, num_terms):
    terms = []
    for i in range(1, num_terms + 1):
        terms.extend([np.sin(2 * np.pi * i * value / period),
                      np.cos(2 * np.pi * i * value / period)])
    return terms

# %%
# Define the period of each component (in days)
# For example, we can choose 365 days for yearly seasonality and 30 days for monthly seasonality.
period_monthly = 30
num_terms_monthly = 3

# %%
feature_eng['monthly_terms'] = feature_eng['month'].apply(fourier_terms, args=(period_monthly, num_terms_monthly))

feature_eng[['monthly_sin_1', 'monthly_cos_1', 'monthly_sin_2', 'monthly_cos_2', 'monthly_sin_3', 'monthly_cos_3']] = pd.DataFrame(feature_eng['monthly_terms'].to_list())
feature_eng.drop(columns=["monthly_terms"], inplace=True)
feature_eng.reset_index(drop=True, inplace=True)

feature_eng.head(2)
# Out:
#    Store year_month_first  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1       2010-02-01        41.12      2.5545        NaN        NaN
# 1      1       2010-02-01        41.12      2.5545        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  ...  Type    Size  Dept  \
# 0        NaN        NaN        NaN  211.236828  ...     A  151315     1
# 1        NaN        NaN        NaN  211.236828  ...     A  151315     2
#
#   Monthly_Sales  monthly_sin_1  monthly_cos_1  monthly_sin_2  monthly_cos_2  \
# 0     131963.08       0.406737       0.913545       0.743145       0.669131
# 1     187509.77       0.406737       0.913545       0.743145       0.669131
#
#    monthly_sin_3  monthly_cos_3
# 0       0.951057       0.309017
# 1       0.951057       0.309017
#
# [2 rows x 23 columns]

# %% [markdown]
# ### Model Training

# %%
train_end_date = "2011-12"
lag = 2 #months
test_start_Date = (datetime.datetime.strptime(train_end_date, "%Y-%m").date()+ relativedelta(months=2)).strftime("%Y-%m")

# %%
train = feature_eng[feature_eng["year_month_first"] <= train_end_date].copy()
train.drop(columns=['year_month_first'], inplace=True)
train.reset_index(drop=True, inplace=True)

# %%
train.head(2)
# Out:
#    Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0      1        41.12      2.5545        NaN        NaN        NaN        NaN
# 1      1        41.12      2.5545        NaN        NaN        NaN        NaN
#
#    MarkDown5         CPI  Unemployment  ...  Type    Size Dept  Monthly_Sales  \
# 0        NaN  211.236828         8.106  ...     A  151315    1      131963.08
# 1        NaN  211.236828         8.106  ...     A  151315    2      187509.77
#
#    monthly_sin_1  monthly_cos_1  monthly_sin_2  monthly_cos_2  monthly_sin_3  \
# 0       0.406737       0.913545       0.743145       0.669131       0.951057
# 1       0.406737       0.913545       0.743145       0.669131       0.951057
#
#    monthly_cos_3
# 0       0.309017
# 1       0.309017
#
# [2 rows x 22 columns]

# %%
test = feature_eng[feature_eng["year_month_first"] >= test_start_Date].copy()
test.drop(columns=['year_month_first'], inplace=True)
test.reset_index(drop=True, inplace=True)

# %%
test.head(2)
# Out:
#    Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0      1       52.285      3.4595  16931.265    7281.18    68.7925  12626.245
# 1      1       52.285      3.4595  16931.265    7281.18    68.7925  12626.245
#
#    MarkDown5         CPI  Unemployment  ...    Size Dept  Monthly_Sales  \
# 0  6015.6725  220.374964         7.348  ...  151315    1      134683.30
# 1  6015.6725  220.374964         7.348  ...  151315    2      198068.89
#
#    month  monthly_sin_1  monthly_cos_1  monthly_sin_2  monthly_cos_2  \
# 0      2       0.406737       0.913545       0.743145       0.669131
# 1      2       0.406737       0.913545       0.743145       0.669131
#
#    monthly_sin_3  monthly_cos_3
# 0       0.951057       0.309017
# 1       0.951057       0.309017
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Define Model

# %%
mlflow.set_experiment("my-experiment")
mlflow.xgboost.autolog(log_datasets=False)
# Out:
# 2023/07/31 00:46:02 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment' does not exist. Creating a new experiment.

# %%
#mlflow.xgboost.autolog()
n_estimators = 10
seed= 123
tree_method = "approx"
enable_categorical = True
objective = 'reg:squarederror'

# %%
train.dtypes
# Out:
# Store              int64
# Temperature      float64
# Fuel_Price       float64
# MarkDown1        float64
# MarkDown2        float64
# MarkDown3        float64
# MarkDown4        float64
# MarkDown5        float64
# CPI              float64
# Unemployment     float64
# IsHoliday          int64
# month              int32
# Type              object
# Size               int64
# Dept               int64
# Monthly_Sales    float64
# monthly_sin_1    float64
# monthly_cos_1    float64
# monthly_sin_2    float64
# monthly_cos_2    float64
# monthly_sin_3    float64
# monthly_cos_3    float64
# dtype: object

# %%
with mlflow.start_run():
    mlflow.log_param("n_estimators", n_estimators)
    mlflow.log_param("seed", 123)
    mlflow.log_param("tree_method", "approx")
    mlflow.log_param("enable_categorical", True)
    mlflow.log_param("objective", 'reg:squarederror')

    xgb_r = xgb.XGBRegressor(objective = objective,
                  n_estimators = n_estimators, seed = seed, tree_method=tree_method, enable_categorical=enable_categorical, max_cat_to_onehot=1)
    
    
    # Fitting the model
    cols = [col for col in train.columns if (col != "Monthly_Sales" and col != "Type")]
    
    X = train[cols]
    print(X.columns)
    y = train["Monthly_Sales"]
    xgb_r.fit(X, y)
    #save col order
    #save categorical transformer
      
    # Predict the model
    pred = xgb_r.predict(test[cols])

    ## Save model
    filename = "models/xgb_retail.bin"
    os.makedirs(os.path.dirname(filename), exist_ok=True)
    with open(filename, "wb") as file:
        pickle.dump((xgb_r, cols), file)
    # mlflow.xgboost.log_model(xgb_r, artifact_path="model")

  
    
    # RMSE Computation
    mse = mean_squared_error(test["Monthly_Sales"], pred)
    mlflow.log_metric("RMSE", math.sqrt(mse))
    print("RMSE : % f" %(math.sqrt(mse)))
# Out:
# Index(['Store', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday', 'month', 'Size', 'Dept', 'monthly_sin_1', 'monthly_cos_1',
#        'monthly_sin_2', 'monthly_cos_2', 'monthly_sin_3', 'monthly_cos_3'],
#       dtype='object')
# 2023/07/31 00:46:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/31 00:46:10 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/31 00:46:10 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# RMSE :  41491.754569

# %%
cols

# %% [markdown]
# ### Hyperparameter Tuning

# %%
mlflow.end_run()

# %%
def objective(trial):
    params = {
    'tree_method': 'approx',
    'max_depth': trial.suggest_int('max_depth', 1, 9),
    'learning_rate': trial.suggest_float('learning_rate', 0.01, 1.0, log=True),
    'n_estimators': trial.suggest_int('n_estimators', 50, 500),
    'min_child_weight': trial.suggest_int('min_child_weight', 1, 10, log=True),
    'gamma': trial.suggest_float('gamma', 1e-8, 1.0),
    'subsample': trial.suggest_float('subsample', 0.01, 1.0),
    'colsample_bytree': trial.suggest_float('colsample_bytree', 0.01, 1.0,log=True),
    'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0, log=True),
    'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0, log=True),
    }
    with mlflow.start_run():
        mlflow.set_tag("version", "tuned_v2") #add tags to additional groupings
        """Define the objective function"""
    
        # Fit the model
        model = xgb.XGBRegressor(**params)

        cols = [col for col in train.columns if (col != "Monthly_Sales" and col != "Type")]
        X = train[cols]
        y = train["Monthly_Sales"]
        model.fit(X, y)
    
        # Make predictions
        y_pred = model.predict(test[cols])
    
        # Evaluate predictions
        mse = mean_squared_error(test["Monthly_Sales"], y_pred)
        rmse = math.sqrt(mse)
        mlflow.log_metric("rmse", math.sqrt(mse))
    return rmse

# %%
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=100, timeout=600)
# Out:
# [I 2023-07-29 23:30:26,404] A new study created in memory with name: no-name-17c75258-470e-47ef-9268-445e6cf1eb27
# 2023/07/29 23:30:27 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:28,488] Trial 0 finished with value: 67119.45237729332 and parameters: {'max_depth': 3, 'learning_rate': 0.05663763471261454, 'n_estimators': 168, 'min_child_weight': 1, 'gamma': 0.9203666963727942, 'subsample': 0.15458400491229496, 'colsample_bytree': 0.18318909823826893, 'reg_alpha': 0.0004297230297505684, 'reg_lambda': 6.335487380799085e-08}. Best is trial 0 with value: 67119.45237729332.
# 2023/07/29 23:30:30 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:31 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:31 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:31,364] Trial 1 finished with value: 55475.106715756534 and parameters: {'max_depth': 8, 'learning_rate': 0.10694867828045648, 'n_estimators': 423, 'min_child_weight': 1, 'gamma': 0.7221822805868401, 'subsample': 0.7697062176988949, 'colsample_bytree': 0.0795789946139105, 'reg_alpha': 0.004495988157127503, 'reg_lambda': 0.00016010676019869135}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:31 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:33 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:33 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:33,225] Trial 2 finished with value: 83161.47316114731 and parameters: {'max_depth': 1, 'learning_rate': 0.2955435223793868, 'n_estimators': 289, 'min_child_weight': 5, 'gamma': 0.6912394047233613, 'subsample': 0.02184550558492163, 'colsample_bytree': 0.027479881326897188, 'reg_alpha': 0.000719352608816631, 'reg_lambda': 0.3010243902646322}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:34 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:35 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:35 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:35,334] Trial 3 finished with value: 65962.89168027742 and parameters: {'max_depth': 7, 'learning_rate': 0.5409513185670762, 'n_estimators': 173, 'min_child_weight': 5, 'gamma': 0.8274560590630856, 'subsample': 0.6272317379096677, 'colsample_bytree': 0.1184566138991627, 'reg_alpha': 0.00015786941578199677, 'reg_lambda': 1.6665234748328856e-08}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:35 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:37 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:37 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:37,146] Trial 4 finished with value: 88128.82132303179 and parameters: {'max_depth': 3, 'learning_rate': 0.030318538966446523, 'n_estimators': 116, 'min_child_weight': 2, 'gamma': 0.9104942377213443, 'subsample': 0.9214798846172032, 'colsample_bytree': 0.016757650890667893, 'reg_alpha': 7.4454125488647886e-06, 'reg_lambda': 0.002319516680356004}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:38 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:39,161] Trial 5 finished with value: 88637.63985720201 and parameters: {'max_depth': 7, 'learning_rate': 0.01946452248796062, 'n_estimators': 96, 'min_child_weight': 9, 'gamma': 0.03426518078367028, 'subsample': 0.3269141649479046, 'colsample_bytree': 0.015947850141501244, 'reg_alpha': 0.4332856941561965, 'reg_lambda': 0.00024934449800971504}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:40 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:41 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:41 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:41,273] Trial 6 finished with value: 73851.92524538605 and parameters: {'max_depth': 3, 'learning_rate': 0.04293064512840361, 'n_estimators': 242, 'min_child_weight': 1, 'gamma': 0.7776755915653517, 'subsample': 0.9637960711804893, 'colsample_bytree': 0.13399315017290853, 'reg_alpha': 0.6995522564580725, 'reg_lambda': 2.155249063183348e-07}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:42 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:43 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:43 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:43,537] Trial 7 finished with value: 57594.136440362 and parameters: {'max_depth': 9, 'learning_rate': 0.5309014809059771, 'n_estimators': 196, 'min_child_weight': 1, 'gamma': 0.5979709085714577, 'subsample': 0.7250441606898904, 'colsample_bytree': 0.01003391185332785, 'reg_alpha': 8.754826606567293e-05, 'reg_lambda': 0.105891413848644}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:43 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:45 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:45 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:45,162] Trial 8 finished with value: 87514.87073125243 and parameters: {'max_depth': 3, 'learning_rate': 0.07871436512264116, 'n_estimators': 50, 'min_child_weight': 3, 'gamma': 0.31547389959332783, 'subsample': 0.04609712266831873, 'colsample_bytree': 0.021703014777601625, 'reg_alpha': 0.0019827021635656673, 'reg_lambda': 1.1572606029986883e-07}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:46 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:47 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:47 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:48,045] Trial 9 finished with value: 91914.75813518053 and parameters: {'max_depth': 8, 'learning_rate': 0.365461163236728, 'n_estimators': 366, 'min_child_weight': 2, 'gamma': 0.5575167360709792, 'subsample': 0.08628558741229311, 'colsample_bytree': 0.04135174179474201, 'reg_alpha': 7.359297450003619e-06, 'reg_lambda': 4.204722253610793e-05}. Best is trial 1 with value: 55475.106715756534.
# 2023/07/29 23:30:49 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:51 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:51 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:51,177] Trial 10 finished with value: 32008.617809984986 and parameters: {'max_depth': 6, 'learning_rate': 0.16657265569326188, 'n_estimators': 493, 'min_child_weight': 1, 'gamma': 0.9821591093557709, 'subsample': 0.45708039665653344, 'colsample_bytree': 0.8287701285379987, 'reg_alpha': 2.1688916667815173e-07, 'reg_lambda': 3.420203872056459e-05}. Best is trial 10 with value: 32008.617809984986.
# 2023/07/29 23:30:53 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:54 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:54 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:54,248] Trial 11 finished with value: 30544.113064116736 and parameters: {'max_depth': 6, 'learning_rate': 0.11530224372348624, 'n_estimators': 499, 'min_child_weight': 1, 'gamma': 0.9611695790020816, 'subsample': 0.4873801603027685, 'colsample_bytree': 0.6073057956935191, 'reg_alpha': 1.0253989931976508e-08, 'reg_lambda': 7.8120468610764e-06}. Best is trial 11 with value: 30544.113064116736.
# 2023/07/29 23:30:55 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:30:57 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:30:57 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:30:57,136] Trial 12 finished with value: 34006.553974161354 and parameters: {'max_depth': 5, 'learning_rate': 0.14178487881206092, 'n_estimators': 480, 'min_child_weight': 1, 'gamma': 0.9930983063591489, 'subsample': 0.45509611024441354, 'colsample_bytree': 0.9949879460560053, 'reg_alpha': 1.0938786838487456e-08, 'reg_lambda': 3.558436170661152e-06}. Best is trial 11 with value: 30544.113064116736.
# 2023/07/29 23:30:58 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:31:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:31:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:31:00,133] Trial 13 finished with value: 37917.53691890366 and parameters: {'max_depth': 5, 'learning_rate': 0.18123431216400354, 'n_estimators': 500, 'min_child_weight': 2, 'gamma': 0.9485703766938035, 'subsample': 0.42357273296652914, 'colsample_bytree': 0.8564810866873319, 'reg_alpha': 2.7356412294665675e-08, 'reg_lambda': 3.191081949939056e-06}. Best is trial 11 with value: 30544.113064116736.
# 2023/07/29 23:31:01 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:31:02 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:31:02 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:31:03,050] Trial 14 finished with value: 122952.4500894008 and parameters: {'max_depth': 6, 'learning_rate': 0.904608922709239, 'n_estimators': 384, 'min_child_weight': 1, 'gamma': 0.8107134523699157, 'subsample': 0.5490501794378451, 'colsample_bytree': 0.48966290190375045, 'reg_alpha': 1.299085515165208e-07, 'reg_lambda': 6.427603988910146e-06}. Best is trial 11 with value: 30544.113064116736.
# 2023/07/29 23:31:04 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:31:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:31:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:31:05,856] Trial 15 finished with value: 41645.996739279326 and parameters: {'max_depth': 6, 'learning_rate': 0.18998787711430098, 'n_estimators': 436, 'min_child_weight': 2, 'gamma': 0.9901350307805087, 'subsample': 0.30298831172498397, 'colsample_bytree': 0.37399569083969264, 'reg_alpha': 1.6711880249433073e-07, 'reg_lambda': 0.004458240918640161}. Best is trial 11 with value: 30544.113064116736.
# 2023/07/29 23:31:06 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:31:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:31:08 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:31:08,098] Trial 16 finished with value: 38847.558054338675 and parameters: {'max_depth': 4, 'learning_rate': 0.07461631921830765, 'n_estimators': 322, 'min_child_weight': 1, 'gamma': 0.8320897669466285, 'subsample': 0.543986716036088, 'colsample_bytree': 0.40896456504971845, 'reg_alpha': 2.770337621511728e-07, 'reg_lambda': 2.1165564734931295e-05}. Best is trial 11 with value: 30544.113064116736.
# 2023/07/29 23:31:09 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:31:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:31:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:31:11,092] Trial 17 finished with value: 48957.77738679357 and parameters: {'max_depth': 6, 'learning_rate': 0.0141481661982181, 'n_estimators': 440, 'min_child_weight': 3, 'gamma': 0.6585509215270823, 'subsample': 0.3406645748698608, 'colsample_bytree': 0.25195975869916715, 'reg_alpha': 1.0902664892339944e-08, 'reg_lambda': 7.807887066218346e-07}. Best is trial 11 with value: 30544.113064116736.
# 2023/07/29 23:31:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:31:13 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:31:13 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:31:13,112] Trial 18 finished with value: 71127.70749104943 and parameters: {'max_depth': 1, 'learning_rate': 0.12115414612481211, 'n_estimators': 374, 'min_child_weight': 1, 'gamma': 0.46830675772793273, 'subsample': 0.2150261885192999, 'colsample_bytree': 0.6969003422513652, 'reg_alpha': 1.3215548891506987e-06, 'reg_lambda': 1.5797570455775878e-06}. Best is trial 11 with value: 30544.113064116736.
# 2023/07/29 23:31:15 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:31:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:31:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:31:16,584] Trial 19 finished with value: 35236.808151157595 and parameters: {'max_depth': 7, 'learning_rate': 0.21350217883047432, 'n_estimators': 478, 'min_child_weight': 2, 'gamma': 0.8659342884462001, 'subsample': 0.4337074548343273, 'colsample_bytree': 0.6382763412800881, 'reg_alpha': 7.883523805264894e-08, 'reg_lambda': 2.3328192481163154e-05}. Best is trial 11 with value: 30544.113064116736.
# ...
# 2023/07/29 23:35:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:35:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:35:11,164] Trial 93 finished with value: 24364.15255269083 and parameters: {'max_depth': 8, 'learning_rate': 0.10746849720936956, 'n_estimators': 407, 'min_child_weight': 8, 'gamma': 0.6636168824298393, 'subsample': 0.9500500195158976, 'colsample_bytree': 0.7320953531230335, 'reg_alpha': 1.0516754331046073e-06, 'reg_lambda': 7.19755305618015e-07}. Best is trial 93 with value: 24364.15255269083.
# 2023/07/29 23:35:13 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:35:14 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:35:14 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:35:14,919] Trial 94 finished with value: 25604.60466422505 and parameters: {'max_depth': 8, 'learning_rate': 0.13453378984438583, 'n_estimators': 408, 'min_child_weight': 8, 'gamma': 0.5932258071257256, 'subsample': 0.9497361156795288, 'colsample_bytree': 0.9236263231365333, 'reg_alpha': 1.0311832612296272e-06, 'reg_lambda': 7.265063158630867e-07}. Best is trial 93 with value: 24364.15255269083.
# 2023/07/29 23:35:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:35:17 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:35:17 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:35:18,001] Trial 95 finished with value: 25982.544885115116 and parameters: {'max_depth': 7, 'learning_rate': 0.11202136975909659, 'n_estimators': 425, 'min_child_weight': 8, 'gamma': 0.6672990514021225, 'subsample': 0.9230246479650581, 'colsample_bytree': 0.7104929392323697, 'reg_alpha': 1.4655829791288161e-06, 'reg_lambda': 5.657515917043361e-07}. Best is trial 93 with value: 24364.15255269083.
# 2023/07/29 23:35:20 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:35:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:35:21 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:35:21,527] Trial 96 finished with value: 24347.266187525427 and parameters: {'max_depth': 8, 'learning_rate': 0.10471734921038262, 'n_estimators': 377, 'min_child_weight': 7, 'gamma': 0.6101786663310514, 'subsample': 0.975983906037993, 'colsample_bytree': 0.7389045548563251, 'reg_alpha': 1.5474435615080415e-07, 'reg_lambda': 1.4501260010962815e-06}. Best is trial 96 with value: 24347.266187525427.
# 2023/07/29 23:35:23 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:35:24 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:35:24 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:35:24,970] Trial 97 finished with value: 25816.770895011832 and parameters: {'max_depth': 8, 'learning_rate': 0.10151447451360458, 'n_estimators': 428, 'min_child_weight': 7, 'gamma': 0.5734725624210743, 'subsample': 0.9758075414356434, 'colsample_bytree': 0.5244764022013297, 'reg_alpha': 1.7704371189255053e-07, 'reg_lambda': 3.223633451395037e-07}. Best is trial 96 with value: 24347.266187525427.
# 2023/07/29 23:35:27 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:35:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:35:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:35:28,316] Trial 98 finished with value: 25308.910243410628 and parameters: {'max_depth': 8, 'learning_rate': 0.1584510231954849, 'n_estimators': 374, 'min_child_weight': 9, 'gamma': 0.6038587751309512, 'subsample': 0.9902018740918064, 'colsample_bytree': 0.5635984181399138, 'reg_alpha': 2.9014193834521966e-08, 'reg_lambda': 6.366885018981712e-07}. Best is trial 96 with value: 24347.266187525427.
# 2023/07/29 23:35:30 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/mlflow/models/signature.py:152: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2023/07/29 23:35:31 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils."
# 2023/07/29 23:35:31 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/Users/kanchanapadmanabhan/Library/CloudStorage/OneDrive-Personal/Personal-Course/Vector/Model Deployment/venv/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# [I 2023-07-29 23:35:31,556] Trial 99 finished with value: 25481.86978356684 and parameters: {'max_depth': 8, 'learning_rate': 0.14689287846982574, 'n_estimators': 370, 'min_child_weight': 9, 'gamma': 0.6189092770753519, 'subsample': 0.9937130000310193, 'colsample_bytree': 0.7536418495500699, 'reg_alpha': 5.197694243103325e-08, 'reg_lambda': 1.5634775214633518e-06}. Best is trial 96 with value: 24347.266187525427.

# %%
study.best_trial
# Out:
# FrozenTrial(number=0, state=TrialState.COMPLETE, values=[67964.84448418471], datetime_start=datetime.datetime(2023, 7, 29, 23, 20, 42, 825205), datetime_complete=datetime.datetime(2023, 7, 29, 23, 20, 46, 847595), params={'max_depth': 2, 'learning_rate': 0.9279097267781184, 'n_estimators': 308, 'min_child_weight': 6, 'gamma': 0.2055048638668166, 'subsample': 0.2152304345905234, 'colsample_bytree': 0.01857075186710803, 'reg_alpha': 2.967452552671559e-05, 'reg_lambda': 0.0007139556712167809}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'max_depth': IntDistribution(high=9, log=False, low=1, step=1), 'learning_rate': FloatDistribution(high=1.0, log=True, low=0.01, step=None), 'n_estimators': IntDistribution(high=500, log=False, low=50, step=1), 'min_child_weight': IntDistribution(high=10, log=True, low=1, step=1), 'gamma': FloatDistribution(high=1.0, log=False, low=1e-08, step=None), 'subsample': FloatDistribution(high=1.0, log=False, low=0.01, step=None), 'colsample_bytree': FloatDistribution(high=1.0, log=True, low=0.01, step=None), 'reg_alpha': FloatDistribution(high=1.0, log=True, low=1e-08, step=None), 'reg_lambda': FloatDistribution(high=1.0, log=True, low=1e-08, step=None)}, trial_id=0, value=None)
